# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
cov = np.cov(X.T)
print(means)
print(cov)
# Out:
# [-0.06143179  0.04569703]
# [[ 4.49842533 -2.78562626]
#  [-2.78562626  5.66051393]]

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
X2_rv=multivariate_normal(means, cov)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])

x, y = np.mgrid[-10:10:.01, -10:10:.01]
pos = np.dstack((x, y))

plt.contour(x, y, X2_rv.pdf(pos))
plt.show()

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
import numpy.linalg as alg

X2_rv=multivariate_normal(means, cov)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])

x, y = np.mgrid[-10:10:.01, -10:10:.01]
pos = np.dstack((x, y))

u, v = alg.eig(cov)
print(u)

plt.contour(x, y, X2_rv.pdf(pos))

plt.arrow(means[0], means[1], v[0][0], v[1][0], head_width=0.3, head_length=0.4)
plt.arrow(means[0], means[1], v[0][1], v[1][1], head_width=0.3, head_length=0.4)
plt.gca().set_aspect('equal', 'box')
plt.show()
# Out:
# [2.23388953 7.92504973]

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
xs = np.random.uniform(0, 1, 200)
ys = np.random.uniform(0, 1, 200)

X = np.stack([xs, ys], axis=1)
means = X.mean(axis=0)
cov = np.cov(X.T)
print(means)
print(cov)

plt.figure(figsize=(5, 5))
ax = plt.axes(aspect='equal')
ax.set_xlim([-0.5, 1.5])
ax.set_ylim([-0.5, 1.5])

X3_rv=multivariate_normal(means, cov)

x, y = np.mgrid[-1:2:.01, -1:2:.01]
pos = np.dstack((x, y))

u, v = alg.eig(cov)

plt.scatter(xs, ys)
plt.contour(x, y, X3_rv.pdf(pos))
plt.arrow(means[0], means[1], v[0][0], v[1][0])
plt.arrow(means[0], means[1], v[0][1], v[1][1])
plt.show()
# Out:
# [0.49680372 0.48376264]
# [[ 0.08911763 -0.01218495]
#  [-0.01218495  0.08578219]]
