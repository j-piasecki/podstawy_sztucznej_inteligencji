# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2] * pow(x,2) + p3[0][1] * x + p3[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2] * pow(x,2) + p4[0][1] * x + p4[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2] * pow(x,2) + p5[0][1] * x + p5[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.554
# Dependent Variable: y                AIC:                632.7696
# Date:               2022-03-25 14:29 BIC:                637.9799
# No. Observations:   100              Log-Likelihood:     -314.38
# Df Model:           1                F-statistic:        123.8
# Df Residuals:       98               Prob (F-statistic): 4.39e-19
# R-squared:          0.558            Scale:              32.137
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.9093     1.1419   -3.4235   0.0009   -6.1754   -1.6433
# x1         7.1794     0.6451   11.1283   0.0000    5.8991    8.4596
# -----------------------------------------------------------------
# Omnibus:              7.202        Durbin-Watson:           2.223
# Prob(Omnibus):        0.027        Jarque-Bera (JB):        7.011
# Skew:                 0.644        Prob(JB):                0.030
# Kurtosis:             3.159        Condition No.:           4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.819
# Dependent Variable: y                AIC:                543.2287
# Date:               2022-03-25 14:29 BIC:                551.0442
# No. Observations:   100              Log-Likelihood:     -268.61
# Df Model:           2                F-statistic:        225.7
# Df Residuals:       97               Prob (F-statistic): 3.24e-37
# R-squared:          0.823            Scale:              12.999
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     5.5960     1.0721    5.2199   0.0000     3.4682    7.7237
# x1      -11.7592     1.6239   -7.2413   0.0000   -14.9822   -8.5362
# x2        6.2540     0.5189   12.0535   0.0000     5.2243    7.2838
# -----------------------------------------------------------------
# Omnibus:               14.409       Durbin-Watson:          2.215
# Prob(Omnibus):         0.001        Jarque-Bera (JB):       4.244
# Skew:                  0.031        Prob(JB):               0.120
# Kurtosis:              1.993        Condition No.:          25
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.993
# Dependent Variable: y                AIC:                215.2428
# Date:               2022-03-25 14:29 BIC:                225.6635
# No. Observations:   100              Log-Likelihood:     -103.62
# Df Model:           3                F-statistic:        4873.
# Df Residuals:       96               Prob (F-statistic): 9.82e-105
# R-squared:          0.993            Scale:              0.48451
# -------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const       -3.4277    0.2745  -12.4892  0.0000   -3.9725   -2.8829
# x1          26.1231    0.8190   31.8944  0.0000   24.4973   27.7489
# x2         -25.6202    0.6445  -39.7523  0.0000  -26.8995  -24.3409
# x3           7.0859    0.1415   50.0644  0.0000    6.8050    7.3669
# ------------------------------------------------------------------
# Omnibus:               7.921        Durbin-Watson:           2.078
# Prob(Omnibus):         0.019        Jarque-Bera (JB):        3.152
# Skew:                  0.025        Prob(JB):                0.207
# Kurtosis:              2.132        Condition No.:           178
# ==================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -51.3846
# Date:               2022-03-25 14:29 BIC:                -38.3588
# No. Observations:   100              Log-Likelihood:     30.692
# Df Model:           4                F-statistic:        5.341e+04
# Df Residuals:       95               Prob (F-statistic): 2.88e-158
# R-squared:          1.000            Scale:              0.033359
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.1561     0.0957   -12.0804   0.0000   -1.3460   -0.9661
# x1        10.9651     0.4723    23.2185   0.0000   10.0275   11.9026
# x2        -3.2518     0.6432    -5.0557   0.0000   -4.5287   -1.9749
# x3        -4.4000     0.3208   -13.7156   0.0000   -5.0369   -3.7632
# x4         1.9038     0.0528    36.0459   0.0000    1.7990    2.0087
# ------------------------------------------------------------------
# Omnibus:               0.626        Durbin-Watson:           2.165
# Prob(Omnibus):         0.731        Jarque-Bera (JB):        0.456
# Skew:                  0.165        Prob(JB):                0.796
# Kurtosis:              3.008        Condition No.:           1442
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -49.8103
# Date:               2022-03-25 14:29 BIC:                -34.1793
# No. Observations:   100              Log-Likelihood:     30.905
# Df Model:           5                F-statistic:        4.245e+04
# Df Residuals:       94               Prob (F-statistic): 5.82e-156
# R-squared:          1.000            Scale:              0.033571
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -1.1040     0.1264   -8.7337   0.0000   -1.3550   -0.8530
# x1         10.4859     0.8928   11.7448   0.0000    8.7132   12.2586
# x2         -2.1675     1.8299   -1.1845   0.2392   -5.8008    1.4659
# x3         -5.3546     1.5415   -3.4737   0.0008   -8.4153   -2.2939
# x4          2.2616     0.5675    3.9853   0.0001    1.1349    3.3884
# x5         -0.0479     0.0756   -0.6332   0.5281   -0.1980    0.1023
# ------------------------------------------------------------------
# Omnibus:               0.420        Durbin-Watson:           2.135
# Prob(Omnibus):         0.811        Jarque-Bera (JB):        0.307
# Skew:                  0.135        Prob(JB):                0.858
# Kurtosis:              2.980        Condition No.:           11814
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     123.8
# Date:                Fri, 25 Mar 2022   Prob (F-statistic):           4.39e-19
# Time:                        14:30:10   Log-Likelihood:                -314.38
# No. Observations:                 100   AIC:                             632.8
# Df Residuals:                      98   BIC:                             638.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.9093      1.142     -3.424      0.001      -6.175      -1.643
# x              7.1794      0.645     11.128      0.000       5.899       8.460
# ==============================================================================
# Omnibus:                        7.202   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                7.011
# Skew:                           0.644   Prob(JB):                       0.0300
# Kurtosis:                       3.159   Cond. No.                         4.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     225.7
# Date:                Fri, 25 Mar 2022   Prob (F-statistic):           3.24e-37
# Time:                        14:30:10   Log-Likelihood:                -268.61
# No. Observations:                 100   AIC:                             543.2
# Df Residuals:                      97   BIC:                             551.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.5960      1.072      5.220      0.000       3.468       7.724
# x            -11.7592      1.624     -7.241      0.000     -14.982      -8.536
# I(x ** 2)      6.2540      0.519     12.053      0.000       5.224       7.284
# ==============================================================================
# Omnibus:                       14.409   Durbin-Watson:                   2.215
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                4.244
# Skew:                           0.031   Prob(JB):                        0.120
# Kurtosis:                       1.993   Cond. No.                         24.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
